# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Wed May 11 02:37:09 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
# Enter github usename and password if the repo to be cloned is own private 
# from getpass import getpass
# user = getpass('GitHub user')
# password = getpass('GitHub password')
# os.environ['GITHUB_AUTH'] = user + ':' + password

# %%
os.chdir('/content')
# %ls
# Out:
# drive/  sample_data/

# %%
# clone repo
# !git clone https://github.com/sonalrpatel/object-detection-yolo
# Out:
# Cloning into 'object-detection-yolo'...
# remote: Enumerating objects: 659, done.
# remote: Counting objects: 100% (161/161), done.
# remote: Compressing objects: 100% (121/121), done.
# remote: Total 659 (delta 64), reused 119 (delta 31), pack-reused 498
# Receiving objects: 100% (659/659), 13.46 MiB | 9.14 MiB/s, done.
# Resolving deltas: 100% (278/278), done.

# %%
os.chdir('/content/object-detection-yolo')
# %ls
# Out:
# configs.py   dataloader/     main.py             notebooks/   train.py
# convert2.py  diagram.drawio  model/              predict2.py  utils/
# convert.py   font/           model_keras_yolo3/  predict.py
# data/        loss/           model_yolo3_tf2/    README.md

# %%
# download our DarkNet weights 
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2022-05-11 02:37:25--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  23.0MB/s    in 11s
#
# 2022-05-11 02:37:37 (21.5 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# call a Python script to set up our architecture with downloaded pre-trained weights
# !python convert.py data/yolov3.cfg yolov3.weights data/yolov3.h5

# %%
# call a Python script to set up our architecture with downloaded pre-trained weights
# !python convert2.py yolov3.weights data/yolov3_coco.h5

# %%
# load data from zip to data
# !mkdir data/obj
# !mkdir data/obj2
# !unzip /content/drive/MyDrive/10_Python/00_Datasets/VehicleRegistrationPlates.v2.yolokeras.zip -d data/obj/
# !unzip /content/drive/MyDrive/10_Python/00_Datasets/LicensePlateRecognition.v6i.yolokeras.zip -d data/obj2/

# %%
# train model
# !python train.py
# Out:
# 2.8.0
# 2022-05-11 02:47:42.816381: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Create YOLOv3 model with 9 anchors and 1 classes.
# Load weights data/yolov3_coco.h5.
# WARNING:tensorflow:Skipping loading weights for layer #249 (named conv_81) due to mismatch in shape for weight conv_81/kernel:0. Weight expects shape (1, 1, 1024, 18). Received saved weight with shape (255, 1024, 1, 1)
# WARNING:tensorflow:Skipping loading weights for layer #249 (named conv_81) due to mismatch in shape for weight conv_81/bias:0. Weight expects shape (18,). Received saved weight with shape (255,)
# WARNING:tensorflow:Skipping loading weights for layer #250 (named conv_93) due to mismatch in shape for weight conv_93/kernel:0. Weight expects shape (1, 1, 512, 18). Received saved weight with shape (255, 512, 1, 1)
# WARNING:tensorflow:Skipping loading weights for layer #250 (named conv_93) due to mismatch in shape for weight conv_93/bias:0. Weight expects shape (18,). Received saved weight with shape (255,)
# WARNING:tensorflow:Skipping loading weights for layer #251 (named conv_105) due to mismatch in shape for weight conv_105/kernel:0. Weight expects shape (1, 1, 256, 18). Received saved weight with shape (255, 256, 1, 1)
# WARNING:tensorflow:Skipping loading weights for layer #251 (named conv_105) due to mismatch in shape for weight conv_105/bias:0. Weight expects shape (18,). Received saved weight with shape (255,)
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv_0 (Conv2D)                (None, None, None,   864         ['input_1[0][0]']
#                                 32)
#
#  bnorm_0 (BatchNormalization)   (None, None, None,   128         ['conv_0[0][0]']
#                                 32)
#
#  leaky_0 (LeakyReLU)            (None, None, None,   0           ['bnorm_0[0][0]']
#                                 32)
#
#  zero_padding2d (ZeroPadding2D)  (None, None, None,   0          ['leaky_0[0][0]']
#                                 32)
#
#  conv_1 (Conv2D)                (None, None, None,   18432       ['zero_padding2d[0][0]']
#                                 64)
#
#  bnorm_1 (BatchNormalization)   (None, None, None,   256         ['conv_1[0][0]']
#                                 64)
#
#  leaky_1 (LeakyReLU)            (None, None, None,   0           ['bnorm_1[0][0]']
#                                 64)
#
#  conv_2 (Conv2D)                (None, None, None,   2048        ['leaky_1[0][0]']
#                                 32)
#
#  bnorm_2 (BatchNormalization)   (None, None, None,   128         ['conv_2[0][0]']
#                                 32)
#
#  leaky_2 (LeakyReLU)            (None, None, None,   0           ['bnorm_2[0][0]']
#                                 32)
#
#  conv_3 (Conv2D)                (None, None, None,   18432       ['leaky_2[0][0]']
#                                 64)
#
#  bnorm_3 (BatchNormalization)   (None, None, None,   256         ['conv_3[0][0]']
#                                 64)
#
#  leaky_3 (LeakyReLU)            (None, None, None,   0           ['bnorm_3[0][0]']
#                                 64)
#
#  add (Add)                      (None, None, None,   0           ['leaky_1[0][0]',
#                                 64)                               'leaky_3[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (None, None, None,   0          ['add[0][0]']
#  D)                             64)
#
#  conv_5 (Conv2D)                (None, None, None,   73728       ['zero_padding2d_1[0][0]']
#                                 128)
#
#  bnorm_5 (BatchNormalization)   (None, None, None,   512         ['conv_5[0][0]']
#                                 128)
#
#  leaky_5 (LeakyReLU)            (None, None, None,   0           ['bnorm_5[0][0]']
#                                 128)
#
#  conv_6 (Conv2D)                (None, None, None,   8192        ['leaky_5[0][0]']
#                                 64)
#
#  bnorm_6 (BatchNormalization)   (None, None, None,   256         ['conv_6[0][0]']
#                                 64)
#
#  leaky_6 (LeakyReLU)            (None, None, None,   0           ['bnorm_6[0][0]']
#                                 64)
#
#  conv_7 (Conv2D)                (None, None, None,   73728       ['leaky_6[0][0]']
#                                 128)
#
#  bnorm_7 (BatchNormalization)   (None, None, None,   512         ['conv_7[0][0]']
#                                 128)
#
#  leaky_7 (LeakyReLU)            (None, None, None,   0           ['bnorm_7[0][0]']
#                                 128)
#
#  add_1 (Add)                    (None, None, None,   0           ['leaky_5[0][0]',
#                                 128)                              'leaky_7[0][0]']
#
#  conv_9 (Conv2D)                (None, None, None,   8192        ['add_1[0][0]']
#                                 64)
#
#  bnorm_9 (BatchNormalization)   (None, None, None,   256         ['conv_9[0][0]']
#                                 64)
#
#  leaky_9 (LeakyReLU)            (None, None, None,   0           ['bnorm_9[0][0]']
#                                 64)
#
#  conv_10 (Conv2D)               (None, None, None,   73728       ['leaky_9[0][0]']
#                                 128)
#
#  bnorm_10 (BatchNormalization)  (None, None, None,   512         ['conv_10[0][0]']
#                                 128)
#
#  leaky_10 (LeakyReLU)           (None, None, None,   0           ['bnorm_10[0][0]']
#                                 128)
#
#  add_2 (Add)                    (None, None, None,   0           ['add_1[0][0]',
#                                 128)                              'leaky_10[0][0]']
#
#  zero_padding2d_2 (ZeroPadding2  (None, None, None,   0          ['add_2[0][0]']
#  D)                             128)
#
#  conv_12 (Conv2D)               (None, None, None,   294912      ['zero_padding2d_2[0][0]']
#                                 256)
#
#  bnorm_12 (BatchNormalization)  (None, None, None,   1024        ['conv_12[0][0]']
#                                 256)
#
#  leaky_12 (LeakyReLU)           (None, None, None,   0           ['bnorm_12[0][0]']
#                                 256)
#
#  conv_13 (Conv2D)               (None, None, None,   32768       ['leaky_12[0][0]']
#                                 128)
#
#  bnorm_13 (BatchNormalization)  (None, None, None,   512         ['conv_13[0][0]']
#                                 128)
#
#  leaky_13 (LeakyReLU)           (None, None, None,   0           ['bnorm_13[0][0]']
#                                 128)
#
#  conv_14 (Conv2D)               (None, None, None,   294912      ['leaky_13[0][0]']
#                                 256)
#
#  bnorm_14 (BatchNormalization)  (None, None, None,   1024        ['conv_14[0][0]']
#                                 256)
#
#  leaky_14 (LeakyReLU)           (None, None, None,   0           ['bnorm_14[0][0]']
#                                 256)
#
#  add_3 (Add)                    (None, None, None,   0           ['leaky_12[0][0]',
#                                 256)                              'leaky_14[0][0]']
#
#  conv_16 (Conv2D)               (None, None, None,   32768       ['add_3[0][0]']
#                                 128)
#
#  bnorm_16 (BatchNormalization)  (None, None, None,   512         ['conv_16[0][0]']
#                                 128)
#
#  leaky_16 (LeakyReLU)           (None, None, None,   0           ['bnorm_16[0][0]']
#                                 128)
#
#  conv_17 (Conv2D)               (None, None, None,   294912      ['leaky_16[0][0]']
#                                 256)
#
#  bnorm_17 (BatchNormalization)  (None, None, None,   1024        ['conv_17[0][0]']
#                                 256)
#
#  leaky_17 (LeakyReLU)           (None, None, None,   0           ['bnorm_17[0][0]']
#                                 256)
#
#  add_4 (Add)                    (None, None, None,   0           ['add_3[0][0]',
#                                 256)                              'leaky_17[0][0]']
#
#  conv_19 (Conv2D)               (None, None, None,   32768       ['add_4[0][0]']
#                                 128)
#
#  bnorm_19 (BatchNormalization)  (None, None, None,   512         ['conv_19[0][0]']
#                                 128)
#
#  leaky_19 (LeakyReLU)           (None, None, None,   0           ['bnorm_19[0][0]']
#                                 128)
#
#  conv_20 (Conv2D)               (None, None, None,   294912      ['leaky_19[0][0]']
#                                 256)
#
#  bnorm_20 (BatchNormalization)  (None, None, None,   1024        ['conv_20[0][0]']
#                                 256)
#
#  leaky_20 (LeakyReLU)           (None, None, None,   0           ['bnorm_20[0][0]']
#                                 256)
#
#  add_5 (Add)                    (None, None, None,   0           ['add_4[0][0]',
#                                 256)                              'leaky_20[0][0]']
#
#  conv_22 (Conv2D)               (None, None, None,   32768       ['add_5[0][0]']
#                                 128)
#
#  bnorm_22 (BatchNormalization)  (None, None, None,   512         ['conv_22[0][0]']
#                                 128)
#
#  leaky_22 (LeakyReLU)           (None, None, None,   0           ['bnorm_22[0][0]']
#                                 128)
#
#  conv_23 (Conv2D)               (None, None, None,   294912      ['leaky_22[0][0]']
#                                 256)
#
#  bnorm_23 (BatchNormalization)  (None, None, None,   1024        ['conv_23[0][0]']
#                                 256)
#
#  leaky_23 (LeakyReLU)           (None, None, None,   0           ['bnorm_23[0][0]']
#                                 256)
#
#  add_6 (Add)                    (None, None, None,   0           ['add_5[0][0]',
#                                 256)                              'leaky_23[0][0]']
#
#  conv_25 (Conv2D)               (None, None, None,   32768       ['add_6[0][0]']
#                                 128)
#
#  bnorm_25 (BatchNormalization)  (None, None, None,   512         ['conv_25[0][0]']
#                                 128)
#
#  leaky_25 (LeakyReLU)           (None, None, None,   0           ['bnorm_25[0][0]']
#                                 128)
#
#  conv_26 (Conv2D)               (None, None, None,   294912      ['leaky_25[0][0]']
#                                 256)
#
#  bnorm_26 (BatchNormalization)  (None, None, None,   1024        ['conv_26[0][0]']
#                                 256)
#
#  leaky_26 (LeakyReLU)           (None, None, None,   0           ['bnorm_26[0][0]']
#                                 256)
#
#  add_7 (Add)                    (None, None, None,   0           ['add_6[0][0]',
#                                 256)                              'leaky_26[0][0]']
#
#  conv_28 (Conv2D)               (None, None, None,   32768       ['add_7[0][0]']
#                                 128)
#
#  bnorm_28 (BatchNormalization)  (None, None, None,   512         ['conv_28[0][0]']
#                                 128)
#
#  leaky_28 (LeakyReLU)           (None, None, None,   0           ['bnorm_28[0][0]']
#                                 128)
#
#  conv_29 (Conv2D)               (None, None, None,   294912      ['leaky_28[0][0]']
#                                 256)
#
#  bnorm_29 (BatchNormalization)  (None, None, None,   1024        ['conv_29[0][0]']
#                                 256)
#
#  leaky_29 (LeakyReLU)           (None, None, None,   0           ['bnorm_29[0][0]']
#                                 256)
#
#  add_8 (Add)                    (None, None, None,   0           ['add_7[0][0]',
#                                 256)                              'leaky_29[0][0]']
#
#  conv_31 (Conv2D)               (None, None, None,   32768       ['add_8[0][0]']
#                                 128)
#
#  bnorm_31 (BatchNormalization)  (None, None, None,   512         ['conv_31[0][0]']
#                                 128)
#
#  leaky_31 (LeakyReLU)           (None, None, None,   0           ['bnorm_31[0][0]']
#                                 128)
#
#  conv_32 (Conv2D)               (None, None, None,   294912      ['leaky_31[0][0]']
#                                 256)
#
#  bnorm_32 (BatchNormalization)  (None, None, None,   1024        ['conv_32[0][0]']
#                                 256)
#
#  leaky_32 (LeakyReLU)           (None, None, None,   0           ['bnorm_32[0][0]']
#                                 256)
#
#  add_9 (Add)                    (None, None, None,   0           ['add_8[0][0]',
#                                 256)                              'leaky_32[0][0]']
#
#  conv_34 (Conv2D)               (None, None, None,   32768       ['add_9[0][0]']
#                                 128)
#
#  bnorm_34 (BatchNormalization)  (None, None, None,   512         ['conv_34[0][0]']
#                                 128)
#
#  leaky_34 (LeakyReLU)           (None, None, None,   0           ['bnorm_34[0][0]']
#                                 128)
#
#  conv_35 (Conv2D)               (None, None, None,   294912      ['leaky_34[0][0]']
#                                 256)
#
#  bnorm_35 (BatchNormalization)  (None, None, None,   1024        ['conv_35[0][0]']
#                                 256)
#
#  leaky_35 (LeakyReLU)           (None, None, None,   0           ['bnorm_35[0][0]']
#                                 256)
#
#  add_10 (Add)                   (None, None, None,   0           ['add_9[0][0]',
#                                 256)                              'leaky_35[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, None, None,   0          ['add_10[0][0]']
#  D)                             256)
#
#  conv_37 (Conv2D)               (None, None, None,   1179648     ['zero_padding2d_3[0][0]']
#                                 512)
#
#  bnorm_37 (BatchNormalization)  (None, None, None,   2048        ['conv_37[0][0]']
#                                 512)
#
#  leaky_37 (LeakyReLU)           (None, None, None,   0           ['bnorm_37[0][0]']
#                                 512)
#
#  conv_38 (Conv2D)               (None, None, None,   131072      ['leaky_37[0][0]']
#                                 256)
#
#  bnorm_38 (BatchNormalization)  (None, None, None,   1024        ['conv_38[0][0]']
#                                 256)
#
#  leaky_38 (LeakyReLU)           (None, None, None,   0           ['bnorm_38[0][0]']
#                                 256)
#
#  conv_39 (Conv2D)               (None, None, None,   1179648     ['leaky_38[0][0]']
#                                 512)
#
#  bnorm_39 (BatchNormalization)  (None, None, None,   2048        ['conv_39[0][0]']
#                                 512)
#
#  leaky_39 (LeakyReLU)           (None, None, None,   0           ['bnorm_39[0][0]']
#                                 512)
#
#  add_11 (Add)                   (None, None, None,   0           ['leaky_37[0][0]',
#                                 512)                              'leaky_39[0][0]']
#
#  conv_41 (Conv2D)               (None, None, None,   131072      ['add_11[0][0]']
#                                 256)
#
#  bnorm_41 (BatchNormalization)  (None, None, None,   1024        ['conv_41[0][0]']
#                                 256)
#
#  leaky_41 (LeakyReLU)           (None, None, None,   0           ['bnorm_41[0][0]']
#                                 256)
#
#  conv_42 (Conv2D)               (None, None, None,   1179648     ['leaky_41[0][0]']
#                                 512)
#
#  bnorm_42 (BatchNormalization)  (None, None, None,   2048        ['conv_42[0][0]']
#                                 512)
#
#  leaky_42 (LeakyReLU)           (None, None, None,   0           ['bnorm_42[0][0]']
#                                 512)
#
#  add_12 (Add)                   (None, None, None,   0           ['add_11[0][0]',
#                                 512)                              'leaky_42[0][0]']
#
#  conv_44 (Conv2D)               (None, None, None,   131072      ['add_12[0][0]']
#                                 256)
#
#  bnorm_44 (BatchNormalization)  (None, None, None,   1024        ['conv_44[0][0]']
#                                 256)
#
#  leaky_44 (LeakyReLU)           (None, None, None,   0           ['bnorm_44[0][0]']
#                                 256)
#
#  conv_45 (Conv2D)               (None, None, None,   1179648     ['leaky_44[0][0]']
#                                 512)
#
#  bnorm_45 (BatchNormalization)  (None, None, None,   2048        ['conv_45[0][0]']
#                                 512)
#
#  leaky_45 (LeakyReLU)           (None, None, None,   0           ['bnorm_45[0][0]']
#                                 512)
#
#  add_13 (Add)                   (None, None, None,   0           ['add_12[0][0]',
#                                 512)                              'leaky_45[0][0]']
#
#  conv_47 (Conv2D)               (None, None, None,   131072      ['add_13[0][0]']
#                                 256)
#
#  bnorm_47 (BatchNormalization)  (None, None, None,   1024        ['conv_47[0][0]']
#                                 256)
#
#  leaky_47 (LeakyReLU)           (None, None, None,   0           ['bnorm_47[0][0]']
#                                 256)
#
#  conv_48 (Conv2D)               (None, None, None,   1179648     ['leaky_47[0][0]']
#                                 512)
#
#  bnorm_48 (BatchNormalization)  (None, None, None,   2048        ['conv_48[0][0]']
#                                 512)
#
#  leaky_48 (LeakyReLU)           (None, None, None,   0           ['bnorm_48[0][0]']
#                                 512)
#
#  add_14 (Add)                   (None, None, None,   0           ['add_13[0][0]',
#                                 512)                              'leaky_48[0][0]']
#
#  conv_50 (Conv2D)               (None, None, None,   131072      ['add_14[0][0]']
#                                 256)
#
#  bnorm_50 (BatchNormalization)  (None, None, None,   1024        ['conv_50[0][0]']
#                                 256)
#
#  leaky_50 (LeakyReLU)           (None, None, None,   0           ['bnorm_50[0][0]']
#                                 256)
#
#  conv_51 (Conv2D)               (None, None, None,   1179648     ['leaky_50[0][0]']
#                                 512)
#
#  bnorm_51 (BatchNormalization)  (None, None, None,   2048        ['conv_51[0][0]']
#                                 512)
#
#  leaky_51 (LeakyReLU)           (None, None, None,   0           ['bnorm_51[0][0]']
#                                 512)
#
#  add_15 (Add)                   (None, None, None,   0           ['add_14[0][0]',
#                                 512)                              'leaky_51[0][0]']
#
#  conv_53 (Conv2D)               (None, None, None,   131072      ['add_15[0][0]']
#                                 256)
#
#  bnorm_53 (BatchNormalization)  (None, None, None,   1024        ['conv_53[0][0]']
#                                 256)
#
#  leaky_53 (LeakyReLU)           (None, None, None,   0           ['bnorm_53[0][0]']
#                                 256)
#
#  conv_54 (Conv2D)               (None, None, None,   1179648     ['leaky_53[0][0]']
#                                 512)
#
#  bnorm_54 (BatchNormalization)  (None, None, None,   2048        ['conv_54[0][0]']
#                                 512)
#
#  leaky_54 (LeakyReLU)           (None, None, None,   0           ['bnorm_54[0][0]']
#                                 512)
#
#  add_16 (Add)                   (None, None, None,   0           ['add_15[0][0]',
#                                 512)                              'leaky_54[0][0]']
#
#  conv_56 (Conv2D)               (None, None, None,   131072      ['add_16[0][0]']
#                                 256)
#
#  bnorm_56 (BatchNormalization)  (None, None, None,   1024        ['conv_56[0][0]']
#                                 256)
#
#  leaky_56 (LeakyReLU)           (None, None, None,   0           ['bnorm_56[0][0]']
#                                 256)
#
#  conv_57 (Conv2D)               (None, None, None,   1179648     ['leaky_56[0][0]']
#                                 512)
#
#  bnorm_57 (BatchNormalization)  (None, None, None,   2048        ['conv_57[0][0]']
#                                 512)
#
#  leaky_57 (LeakyReLU)           (None, None, None,   0           ['bnorm_57[0][0]']
#                                 512)
#
#  add_17 (Add)                   (None, None, None,   0           ['add_16[0][0]',
#                                 512)                              'leaky_57[0][0]']
#
#  conv_59 (Conv2D)               (None, None, None,   131072      ['add_17[0][0]']
#                                 256)
#
#  bnorm_59 (BatchNormalization)  (None, None, None,   1024        ['conv_59[0][0]']
#                                 256)
#
#  leaky_59 (LeakyReLU)           (None, None, None,   0           ['bnorm_59[0][0]']
#                                 256)
#
#  conv_60 (Conv2D)               (None, None, None,   1179648     ['leaky_59[0][0]']
#                                 512)
#
#  bnorm_60 (BatchNormalization)  (None, None, None,   2048        ['conv_60[0][0]']
#                                 512)
#
#  leaky_60 (LeakyReLU)           (None, None, None,   0           ['bnorm_60[0][0]']
#                                 512)
#
#  add_18 (Add)                   (None, None, None,   0           ['add_17[0][0]',
#                                 512)                              'leaky_60[0][0]']
#
#  zero_padding2d_4 (ZeroPadding2  (None, None, None,   0          ['add_18[0][0]']
#  D)                             512)
#
#  conv_62 (Conv2D)               (None, None, None,   4718592     ['zero_padding2d_4[0][0]']
#                                 1024)
#
#  bnorm_62 (BatchNormalization)  (None, None, None,   4096        ['conv_62[0][0]']
# ...
#  bnorm_80 (BatchNormalization)  (None, None, None,   4096        ['conv_80[0][0]']
#                                 1024)
#
#  bnorm_92 (BatchNormalization)  (None, None, None,   2048        ['conv_92[0][0]']
#                                 512)
#
#  bnorm_104 (BatchNormalization)  (None, None, None,   1024       ['conv_104[0][0]']
#                                 256)
#
#  leaky_80 (LeakyReLU)           (None, None, None,   0           ['bnorm_80[0][0]']
#                                 1024)
#
#  leaky_92 (LeakyReLU)           (None, None, None,   0           ['bnorm_92[0][0]']
#                                 512)
#
#  leaky_104 (LeakyReLU)          (None, None, None,   0           ['bnorm_104[0][0]']
#                                 256)
#
#  conv_81 (Conv2D)               (None, None, None,   18450       ['leaky_80[0][0]']
#                                 18)
#
#  conv_93 (Conv2D)               (None, None, None,   9234        ['leaky_92[0][0]']
#                                 18)
#
#  conv_105 (Conv2D)              (None, None, None,   4626        ['leaky_104[0][0]']
#                                 18)
#
#  input_2 (InputLayer)           [(None, 13, 13, 3,   0           []
#                                 6)]
#
#  input_3 (InputLayer)           [(None, 26, 26, 3,   0           []
#                                 6)]
#
#  input_4 (InputLayer)           [(None, 52, 52, 3,   0           []
#                                 6)]
#
#  yolo_loss (Lambda)             ()                   0           ['conv_81[0][0]',
#                                                                   'conv_93[0][0]',
#                                                                   'conv_105[0][0]',
#                                                                   'input_2[0][0]',
#                                                                   'input_3[0][0]',
#                                                                   'input_4[0][0]']
#
# ==================================================================================================
# Total params: 61,576,342
# Trainable params: 61,523,734
# Non-trainable params: 52,608
# __________________________________________________________________________________________________
# Freeze the first 184 layers of total 252 layers.
# Epoch 1/30
# 610/610 [==============================] - ETA: 0s - loss: 102.3835Setting learning rate to 0.0009400000446476042.
# 610/610 [==============================] - 262s 410ms/step - loss: 102.3835 - val_loss: 16.1856
# Epoch 2/30
# 610/610 [==============================] - ETA: 0s - loss: 14.6379Setting learning rate to 0.0008836000529117881.
# 610/610 [==============================] - 246s 402ms/step - loss: 14.6379 - val_loss: 13.5449
# Epoch 3/30
# 610/610 [==============================] - ETA: 0s - loss: 13.1083Setting learning rate to 0.0008305840322282165.
# 610/610 [==============================] - 245s 402ms/step - loss: 13.1083 - val_loss: 12.7052
# Epoch 4/30
# 610/610 [==============================] - ETA: 0s - loss: 12.2947Setting learning rate to 0.0007807489892002195.
# 610/610 [==============================] - 245s 402ms/step - loss: 12.2947 - val_loss: 12.1861
# Epoch 5/30
# 610/610 [==============================] - ETA: 0s - loss: 11.7608Setting learning rate to 0.0007339040772058069.
# 610/610 [==============================] - 245s 401ms/step - loss: 11.7608 - val_loss: 11.8187
# Epoch 6/30
# 610/610 [==============================] - ETA: 0s - loss: 11.3472Setting learning rate to 0.0006898698303848505.
# 610/610 [==============================] - 243s 398ms/step - loss: 11.3472 - val_loss: 11.8552
# Epoch 7/30
# 610/610 [==============================] - ETA: 0s - loss: 11.0714Setting learning rate to 0.0006484776164870709.
# 610/610 [==============================] - 242s 396ms/step - loss: 11.0714 - val_loss: 11.5756
# Epoch 8/30
# 610/610 [==============================] - ETA: 0s - loss: 10.8102Setting learning rate to 0.0006095689802896231.
# 610/610 [==============================] - 242s 396ms/step - loss: 10.8102 - val_loss: 11.5622
# Epoch 9/30
# 610/610 [==============================] - ETA: 0s - loss: 10.6097Setting learning rate to 0.0005729948228690773.
# 610/610 [==============================] - 242s 396ms/step - loss: 10.6097 - val_loss: 11.4018
# Epoch 10/30
# 610/610 [==============================] - ETA: 0s - loss: 10.3946Setting learning rate to 0.0005386151280254125.
# 610/610 [==============================] - 241s 396ms/step - loss: 10.3946 - val_loss: 11.3560
# Epoch 11/30
# 610/610 [==============================] - ETA: 0s - loss: 10.2335Setting learning rate to 0.0005062981962691992.
# 610/610 [==============================] - 241s 395ms/step - loss: 10.2335 - val_loss: 11.5784
# Epoch 12/30
# 610/610 [==============================] - ETA: 0s - loss: 10.1018Setting learning rate to 0.00047592031653039153.
# 610/610 [==============================] - 241s 395ms/step - loss: 10.1018 - val_loss: 11.5756
# Epoch 13/30
# 610/610 [==============================] - ETA: 0s - loss: 9.9787Setting learning rate to 0.00044736510957591233.
# 610/610 [==============================] - 241s 395ms/step - loss: 9.9787 - val_loss: 11.4683
# Epoch 14/30
# 610/610 [==============================] - ETA: 0s - loss: 9.8500Setting learning rate to 0.0004205231997184455.
# 610/610 [==============================] - 241s 395ms/step - loss: 9.8500 - val_loss: 11.4010
# Epoch 15/30
# 610/610 [==============================] - ETA: 0s - loss: 9.7830Setting learning rate to 0.0003952918044524267.
# 610/610 [==============================] - 241s 395ms/step - loss: 9.7830 - val_loss: 11.3801
# Epoch 16/30
# 610/610 [==============================] - ETA: 0s - loss: 9.6962Setting learning rate to 0.0003715742967324331.
# 610/610 [==============================] - 241s 395ms/step - loss: 9.6962 - val_loss: 11.4990
# Epoch 17/30
# 610/610 [==============================] - ETA: 0s - loss: 9.6355Setting learning rate to 0.0003492798493243754.
# 610/610 [==============================] - 241s 395ms/step - loss: 9.6355 - val_loss: 11.6083
# Epoch 18/30
# 610/610 [==============================] - ETA: 0s - loss: 9.5552Setting learning rate to 0.0003283230517990887.
# 610/610 [==============================] - 241s 395ms/step - loss: 9.5552 - val_loss: 11.6196
# Epoch 19/30
# 610/610 [==============================] - ETA: 0s - loss: 9.5112Setting learning rate to 0.0003086236643139273.
# 610/610 [==============================] - 241s 395ms/step - loss: 9.5112 - val_loss: 11.5829
# Epoch 20/30
# 610/610 [==============================] - ETA: 0s - loss: 9.5226Setting learning rate to 0.00029010623460635544.
# 610/610 [==============================] - 241s 395ms/step - loss: 9.5226 - val_loss: 11.6468
# Epoch 20: early stopping
# Unfreeze all the layers.
# Epoch 31/60
#    6/1219 [..............................] - ETA: 8:33 - loss: 11.4529WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1807s vs `on_train_batch_end` time: 0.2530s). Check your callbacks.
# 1219/1219 [==============================] - ETA: 0s - loss: 9.9999 Setting learning rate to 9.399999762536026e-05.
# 1219/1219 [==============================] - 545s 438ms/step - loss: 9.9999 - val_loss: 10.0385
# Epoch 32/60
# 1219/1219 [==============================] - ETA: 0s - loss: 9.0238Setting learning rate to 8.83599957160186e-05.
# 1219/1219 [==============================] - 533s 437ms/step - loss: 9.0238 - val_loss: 9.6236
# Epoch 33/60
# 1219/1219 [==============================] - ETA: 0s - loss: 8.2775Setting learning rate to 8.305839364766143e-05.
# 1219/1219 [==============================] - 532s 437ms/step - loss: 8.2775 - val_loss: 9.4666
# Epoch 34/60
# 1219/1219 [==============================] - ETA: 0s - loss: 7.7180Setting learning rate to 7.807489208062179e-05.
# 1219/1219 [==============================] - 532s 437ms/step - loss: 7.7180 - val_loss: 8.9478
# Epoch 35/60
# 1219/1219 [==============================] - ETA: 0s - loss: 7.2581Setting learning rate to 7.33903954096604e-05.
# 1219/1219 [==============================] - 532s 437ms/step - loss: 7.2581 - val_loss: 8.5910
# Epoch 36/60
# 1219/1219 [==============================] - ETA: 0s - loss: 6.8125Setting learning rate to 6.898697072756476e-05.
# 1219/1219 [==============================] - 532s 437ms/step - loss: 6.8125 - val_loss: 8.3038
# Epoch 37/60
# 1219/1219 [==============================] - ETA: 0s - loss: 6.4403Setting learning rate to 6.484775207354687e-05.
# 1219/1219 [==============================] - 532s 437ms/step - loss: 6.4403 - val_loss: 8.2050
# Epoch 38/60
# 1219/1219 [==============================] - ETA: 0s - loss: 6.1385Setting learning rate to 6.0956885718042025e-05.
# 1219/1219 [==============================] - 533s 437ms/step - loss: 6.1385 - val_loss: 7.8538
# Epoch 39/60
# 1219/1219 [==============================] - ETA: 0s - loss: 5.8600Setting learning rate to 5.7299472027807495e-05.
# 1219/1219 [==============================] - 532s 437ms/step - loss: 5.8600 - val_loss: 7.5707
# Epoch 40/60
# 1219/1219 [==============================] - ETA: 0s - loss: 5.6222Setting learning rate to 5.386150391132105e-05.
# 1219/1219 [==============================] - 532s 437ms/step - loss: 5.6222 - val_loss: 7.5396
# Epoch 41/60
# 1219/1219 [==============================] - ETA: 0s - loss: 5.4253Setting learning rate to 5.062981210357975e-05.
# 1219/1219 [==============================] - 533s 437ms/step - loss: 5.4253 - val_loss: 7.2794
# Epoch 42/60
# 1219/1219 [==============================] - ETA: 0s - loss: 5.1972Setting learning rate to 4.759202412969898e-05.
# 1219/1219 [==============================] - 532s 437ms/step - loss: 5.1972 - val_loss: 7.2294
# Epoch 43/60
# 1219/1219 [==============================] - ETA: 0s - loss: 5.0554Setting learning rate to 4.473650275031105e-05.
# 1219/1219 [==============================] - 532s 436ms/step - loss: 5.0554 - val_loss: 7.3615
# Epoch 44/60
# 1219/1219 [==============================] - ETA: 0s - loss: 4.9010Setting learning rate to 4.205231176456436e-05.
# 1219/1219 [==============================] - 532s 437ms/step - loss: 4.9010 - val_loss: 7.1013
# Epoch 45/60
# 1219/1219 [==============================] - ETA: 0s - loss: 4.7617Setting learning rate to 3.952917155402247e-05.
# 1219/1219 [==============================] - 533s 437ms/step - loss: 4.7617 - val_loss: 6.8786
# Epoch 46/60
# 1219/1219 [==============================] - ETA: 0s - loss: 4.6211Setting learning rate to 3.7157421465963126e-05.
# 1219/1219 [==============================] - 532s 436ms/step - loss: 4.6211 - val_loss: 7.0894
# Epoch 47/60
# 1219/1219 [==============================] - ETA: 0s - loss: 4.5303Setting learning rate to 3.492797535727732e-05.
# 1219/1219 [==============================] - 532s 436ms/step - loss: 4.5303 - val_loss: 6.9266
# Epoch 48/60
# 1219/1219 [==============================] - ETA: 0s - loss: 4.4128Setting learning rate to 3.28322976565687e-05.
# 1219/1219 [==============================] - 532s 437ms/step - loss: 4.4128 - val_loss: 6.7963
# Epoch 49/60
# 1219/1219 [==============================] - ETA: 0s - loss: 4.3096Setting learning rate to 3.086235890805255e-05.
# 1219/1219 [==============================] - 534s 438ms/step - loss: 4.3096 - val_loss: 6.7451
# Epoch 50/60
# 1219/1219 [==============================] - ETA: 0s - loss: 4.2437Setting learning rate to 2.901061867305543e-05.
# 1219/1219 [==============================] - 533s 438ms/step - loss: 4.2437 - val_loss: 6.5581
# Epoch 51/60
# 1219/1219 [==============================] - ETA: 0s - loss: 4.1407Setting learning rate to 2.7269981073914093e-05.
# 1219/1219 [==============================] - 536s 440ms/step - loss: 4.1407 - val_loss: 6.6883
# Epoch 52/60
# 1219/1219 [==============================] - ETA: 0s - loss: 4.0501Setting learning rate to 2.5633782825025262e-05.
# 1219/1219 [==============================] - 536s 440ms/step - loss: 4.0501 - val_loss: 6.8725
# Epoch 53/60
# 1219/1219 [==============================] - ETA: 0s - loss: 3.9894Setting learning rate to 2.409575561614474e-05.
# 1219/1219 [==============================] - 537s 441ms/step - loss: 3.9894 - val_loss: 6.6502
# Epoch 54/60
# 1219/1219 [==============================] - ETA: 0s - loss: 3.8873Setting learning rate to 2.265001072373707e-05.
# 1219/1219 [==============================] - 535s 438ms/step - loss: 3.8873 - val_loss: 6.5849
# Epoch 55/60
# 1219/1219 [==============================] - ETA: 0s - loss: 3.8045Setting learning rate to 2.129100994352484e-05.
# 1219/1219 [==============================] - 532s 437ms/step - loss: 3.8045 - val_loss: 6.5119
# Epoch 56/60
# 1219/1219 [==============================] - ETA: 0s - loss: 3.7556Setting learning rate to 2.001354849198833e-05.
# 1219/1219 [==============================] - 532s 436ms/step - loss: 3.7556 - val_loss: 6.2661
# Epoch 57/60
# 1219/1219 [==============================] - ETA: 0s - loss: 3.6833Setting learning rate to 1.8812736198015045e-05.
# 1219/1219 [==============================] - 532s 436ms/step - loss: 3.6833 - val_loss: 6.4355
# Epoch 58/60
# 1219/1219 [==============================] - ETA: 0s - loss: 3.6078Setting learning rate to 1.768397185514914e-05.
# 1219/1219 [==============================] - 532s 436ms/step - loss: 3.6078 - val_loss: 6.4255
# Epoch 59/60
# 1219/1219 [==============================] - ETA: 0s - loss: 3.5449Setting learning rate to 1.6622932962491175e-05.
# 1219/1219 [==============================] - 531s 436ms/step - loss: 3.5449 - val_loss: 6.3342
# Epoch 60/60
# 1219/1219 [==============================] - ETA: 0s - loss: 3.5222Setting learning rate to 1.5625556916347704e-05.
# 1219/1219 [==============================] - 532s 437ms/step - loss: 3.5222 - val_loss: 6.1093
