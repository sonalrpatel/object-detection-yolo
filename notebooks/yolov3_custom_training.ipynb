# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Thu Oct 20 20:12:20 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
# Enter github usename and password if the repo to be cloned is own private 
# from getpass import getpass
# user = getpass('GitHub user')
# password = getpass('GitHub password')
# os.environ['GITHUB_AUTH'] = user + ':' + password

# %%
os.chdir('/content')
# %ls
# Out:
# drive/  sample_data/

# %%
# clone repo
# !git clone https://github.com/sonalrpatel/object-detection-yolo
# Out:
# Cloning into 'object-detection-yolo'...
# remote: Enumerating objects: 758, done.
# remote: Counting objects: 100% (260/260), done.
# remote: Compressing objects: 100% (184/184), done.
# remote: Total 758 (delta 121), reused 194 (delta 63), pack-reused 498
# Receiving objects: 100% (758/758), 14.10 MiB | 17.73 MiB/s, done.
# Resolving deltas: 100% (335/335), done.

# %%
os.chdir('/content/object-detection-yolo/model_data')
# %ls
# Out:
# simhei.ttf  yolo_anchors.txt  yolov3.cfg

# %%
# download our DarkNet weights 
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2022-10-20 20:13:26--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  20.1MB/s    in 12s
#
# 2022-10-20 20:13:39 (18.9 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
os.chdir('/content/object-detection-yolo/')
# %ls
# Out:
# configs.py   dataloader/     model/              model_yolo3_tf2/  README.md
# convert0.py  diagram.drawio  model_data/         notebooks/        train.py
# convert.py   loss/           model_img/          predict0.py       utils/
# data/        main.py         model_keras_yolo3/  predict.py

# %%
# call a Python script to set up our architecture with downloaded pre-trained weights
# !python convert2.py yolov3.weights data/yolov3_coco.h5

# %%
# call a Python script to set up our architecture with downloaded pre-trained weights
# !python convert.py model_data/yolov3.weights model_data/yolov3_coco.h5

# %%
# load data from zip to data
# !mkdir data/obj
# !mkdir data/obj2
# !unzip /content/drive/MyDrive/10_Python/00_Datasets/VehicleRegistrationPlates.v2.yolokeras.zip -d data/obj/
# !unzip /content/drive/MyDrive/10_Python/00_Datasets/LicensePlateRecognition.v6i.yolokeras.zip -d data/obj2/

# %%
# load images from zip to data
# !unzip /content/drive/MyDrive/10_Python/00_Datasets/bdd100k_images_10k.zip -d data

# %%
# load labels from zip to data
# !unzip /content/drive/MyDrive/10_Python/00_Datasets/bdd100k_det_20_labels_trainval.zip -d data
# Out:
# Archive:  /content/drive/MyDrive/10_Python/00_Datasets/bdd100k_det_20_labels_trainval.zip
#   inflating: data/bdd100k/labels/det_20/det_train.json
#   inflating: data/bdd100k/labels/det_20/det_val.json

# %%
# train model
# !python train.py
# Out:
# 2.9.2
# 2022-10-20 20:33:44.056343: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Create YOLOv3 model with 9 anchors and 13 classes.
# Load weights model_data/yolov3_coco.h5.
# WARNING:tensorflow:Skipping loading weights for layer #249 (named conv_81) due to mismatch in shape for weight conv_81/kernel:0. Weight expects shape (1, 1, 1024, 54). Received saved weight with shape (255, 1024, 1, 1)
# WARNING:tensorflow:Skipping loading weights for layer #249 (named conv_81) due to mismatch in shape for weight conv_81/kernel:0. Weight expects shape (1, 1, 1024, 54). Received saved weight with shape (255, 1024, 1, 1)
# WARNING:tensorflow:Skipping loading weights for layer #249 (named conv_81) due to mismatch in shape for weight conv_81/bias:0. Weight expects shape (54,). Received saved weight with shape (255,)
# ...
